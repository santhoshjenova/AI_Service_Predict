# %% [markdown]
# Data Preprocessing & Cleaning
# 1. Handle Missing Values
#
# Impute missing dates (e.g., follow_up_date) using strategies like median, mode, "Unknown", or custom logic.
#
# For other NaNs (numerical/categorical), use mean/mode or "Unknown" as appropriate.
#
# 2. Convert Date Columns
#
# Convert all date columns (last_service_date, next_service_due_date, follow_up_date, etc.) to datetime using pd.to_datetime().
#
# Extract year, month, day, and calculate intervals (e.g., days since last service).
#
# 3. Encode Categorical Variables
#
# Use OneHotEncoder or pd.get_dummies for variables like location, customer_type, preferred_language, make, model, etc.
#
# Apply LabelEncoder for binary columns (warranty_status, insurance_status, pending_service, etc.).
#
# 4. Drop Sensitive Identifiers
#
# Remove privacy-sensitive or unnecessary columns: customer_id, name, email, mobile_number.
#
# 5. Scale/Normalize Numerical Features
#
# Scale features like odometer_reading, age_of_vehicle, last_service_cost, etc., using StandardScaler or MinMaxScaler.

# %%
import pandas as pd

# %%
df = pd.read_csv('service_dataset.csv')

# %%
df
# Out:
#     customer_id              name  mobile_number  \
# 0      CUST0116    Sabrina Barnes     8945450816
# 1      CUST0368   Steven Johnston     9815728359
# 2      CUST0422  Matthew Gonzalez     8078635658
# 3      CUST0413       Lisa Thomas     6756649998
# 4      CUST0451    Jessica Abbott     6364076742
# ..          ...               ...            ...
# 995    CUST0366     Shawna Palmer     9460106831
# 996    CUST0005    Theresa Martin     6329366782
# 997    CUST0350    Melinda Nelson     9675801524
# 998    CUST0315        Wanda Todd     9752893160
# 999    CUST0383       Joseph Carr     8952736412
#
#                              email                location customer_type  \
# 0           averyshane@stanton.com  South Christianchester        Retail
# 1       tyler23@walsh-mccarthy.com       North Jacksonfort     Corporate
# 2            woodsmelvin@yahoo.com                Halefort        Retail
# 3             tschroeder@yahoo.com              Larryhaven     Corporate
# 4        heatherfarmer@carlson.com          Christinaburgh         Fleet
# ..                             ...                     ...           ...
# 995      josephalvarez@hotmail.com               Bellville        Retail
# 996         chapmanjerry@gmail.com           North Jeanton     Corporate
# 997  jacobsonroy@martin-bailey.biz            Alvarezburgh        Retail
# 998           scottolson@clark.com       West Jessicashire         Fleet
# 999          tayloramy@hotmail.com               Sandraton        Retail
#
#     preferred_language     make   model  year_of_purchase  ...  \
# 0                Tamil     Ford  Aspire              2019  ...
# 1                Tamil   Toyota   Yaris              2019  ...
# 2              English     Ford    Figo              2020  ...
# 3              English    Honda    City              2019  ...
# 4                Hindi    Honda    City              2015  ...
# ..                 ...      ...     ...               ...  ...
# 995              Hindi  Hyundai     i20              2015  ...
# 996              Tamil  Hyundai   Creta              2016  ...
# 997              Tamil   Toyota  Innova              2021  ...
# 998              Tamil  Hyundai     i10              2015  ...
# 999              Hindi   Toyota  Innova              2016  ...
#
#      Whats_delivered Whats_clicked sent_email  clicked_email email_opened  \
# 0                 No            No         No             No           No
# 1                Yes           Yes        Yes             No          Yes
# 2                 No            No         No             No           No
# 3                 No            No        Yes            Yes           No
# 4                Yes           Yes        Yes            Yes           No
# ..               ...           ...        ...            ...          ...
# 995              Yes           Yes         No             No           No
# 996              Yes           Yes        Yes             No           No
# 997              Yes           Yes         No             No           No
# 998              Yes           Yes         No             No           No
# 999               No            No        Yes            Yes           No
#
#     last_service_cost feedback_score pickup_drop_required customer_feedback  \
# 0                9884              4                   No      Poor Service
# 1               10996              4                  Yes         Satisfied
# 2                3213              4                   No           Average
# 3                6601              5                   No    Smooth Process
# 4               14907              3                   No      Unresponsive
# ..                ...            ...                  ...               ...
# 995             11536              3                   No    Delayed Pickup
# 996              6999              4                  Yes    Smooth Process
# 997              3215              4                   No    Delayed Pickup
# 998              9804              1                   No      Unresponsive
# 999             11768              5                   No      Unresponsive
#
#      feedback_date
# 0       11-04-2024
# 1       09-01-2025
# 2       08-03-2025
# 3       19-11-2024
# 4       30-12-2024
# ..             ...
# 995     20-02-2025
# 996     15-10-2024
# 997     15-04-2025
# 998     27-08-2024
# 999     20-10-2024
#
# [1000 rows x 52 columns]

# %%
df.isnull().sum()
# Out:
# customer_id                0
# name                       0
# mobile_number              0
# email                      0
# location                   0
# customer_type              0
# preferred_language         0
# make                       0
# model                      0
# year_of_purchase           0
# age_of_vehicle             0
# fuel_type                  0
# transmission               0
# odometer_reading           0
# warranty_status            0
# insurance_status           0
# last_service_date          0
# last_service_type          0
# service_center             0
# number_of_services         0
# last_service_kms           0
# avg_kms_per_month          0
# next_service_due_kms       0
# next_service_due_date      0
# next_service_due_days      0
# AMC_status                 0
# pending_service            0
# last_call_date             0
# response                   0
# follow_up_required         0
# follow_up_date           494
# telecaller_name            0
# service_booked             0
# call_duration_sec          0
# remark                     0
# eligible_offer_code        0
# offer_description          0
# offer_valid_till           0
# sent_sms                   0
# sms_delivered              0
# sms_clicked                0
# sent_Whats                 0
# Whats_delivered            0
# Whats_clicked              0
# sent_email                 0
# clicked_email              0
# email_opened               0
# last_service_cost          0
# feedback_score             0
# pickup_drop_required       0
# customer_feedback          0
# feedback_date              0
# dtype: int64

# %%
# Fill missing values example
df['follow_up_date'] = pd.to_datetime(df['follow_up_date'], errors='coerce')
df['follow_up_date'].fillna(method='ffill', inplace=True)

# %%
df.isnull().sum()
# Out:
# customer_id              0
# name                     0
# mobile_number            0
# email                    0
# location                 0
# customer_type            0
# preferred_language       0
# make                     0
# model                    0
# year_of_purchase         0
# age_of_vehicle           0
# fuel_type                0
# transmission             0
# odometer_reading         0
# warranty_status          0
# insurance_status         0
# last_service_date        0
# last_service_type        0
# service_center           0
# number_of_services       0
# last_service_kms         0
# avg_kms_per_month        0
# next_service_due_kms     0
# next_service_due_date    0
# next_service_due_days    0
# AMC_status               0
# pending_service          0
# last_call_date           0
# response                 0
# follow_up_required       0
# follow_up_date           4
# telecaller_name          0
# service_booked           0
# call_duration_sec        0
# remark                   0
# eligible_offer_code      0
# offer_description        0
# offer_valid_till         0
# sent_sms                 0
# sms_delivered            0
# sms_clicked              0
# sent_Whats               0
# Whats_delivered          0
# Whats_clicked            0
# sent_email               0
# clicked_email            0
# email_opened             0
# last_service_cost        0
# feedback_score           0
# pickup_drop_required     0
# customer_feedback        0
# feedback_date            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 52 columns):
# customer_id              1000 non-null object
# name                     1000 non-null object
# mobile_number            1000 non-null int64
# email                    1000 non-null object
# location                 1000 non-null object
# customer_type            1000 non-null object
# preferred_language       1000 non-null object
# make                     1000 non-null object
# model                    1000 non-null object
# year_of_purchase         1000 non-null int64
# age_of_vehicle           1000 non-null int64
# fuel_type                1000 non-null object
# transmission             1000 non-null object
# odometer_reading         1000 non-null int64
# warranty_status          1000 non-null object
# insurance_status         1000 non-null object
# last_service_date        1000 non-null object
# last_service_type        1000 non-null object
# service_center           1000 non-null object
# number_of_services       1000 non-null int64
# last_service_kms         1000 non-null int64
# avg_kms_per_month        1000 non-null int64
# next_service_due_kms     1000 non-null int64
# next_service_due_date    1000 non-null object
# next_service_due_days    1000 non-null int64
# AMC_status               1000 non-null object
# pending_service          1000 non-null object
# last_call_date           1000 non-null object
# response                 1000 non-null object
# follow_up_required       1000 non-null object
# follow_up_date           996 non-null datetime64[ns]
# telecaller_name          1000 non-null object
# service_booked           1000 non-null object
# call_duration_sec        1000 non-null int64
# remark                   1000 non-null object
# eligible_offer_code      1000 non-null object
# offer_description        1000 non-null object
# offer_valid_till         1000 non-null object
# sent_sms                 1000 non-null object
# sms_delivered            1000 non-null object
# sms_clicked              1000 non-null object
# sent_Whats               1000 non-null object
# Whats_delivered          1000 non-null object
# Whats_clicked            1000 non-null object
# sent_email               1000 non-null object
# clicked_email            1000 non-null object
# email_opened             1000 non-null object
# last_service_cost        1000 non-null int64
# feedback_score           1000 non-null int64
# pickup_drop_required     1000 non-null object
# customer_feedback        1000 non-null object
# feedback_date            1000 non-null object
# dtypes: datetime64[ns](1), int64(12), object(39)
# memory usage: 406.4+ KB

# %%
df.shape
# Out:
# (1000, 52)

# %%
# Convert dates
date_cols = ['last_service_date', 'next_service_due_date', 'feedback_date']
for col in date_cols:
    df[col] = pd.to_datetime(df[col], errors='coerce')

# %%
df
# Out:
#     customer_id              name  mobile_number  \
# 0      CUST0116    Sabrina Barnes     8945450816
# 1      CUST0368   Steven Johnston     9815728359
# 2      CUST0422  Matthew Gonzalez     8078635658
# 3      CUST0413       Lisa Thomas     6756649998
# 4      CUST0451    Jessica Abbott     6364076742
# ..          ...               ...            ...
# 995    CUST0366     Shawna Palmer     9460106831
# 996    CUST0005    Theresa Martin     6329366782
# 997    CUST0350    Melinda Nelson     9675801524
# 998    CUST0315        Wanda Todd     9752893160
# 999    CUST0383       Joseph Carr     8952736412
#
#                              email                location customer_type  \
# 0           averyshane@stanton.com  South Christianchester        Retail
# 1       tyler23@walsh-mccarthy.com       North Jacksonfort     Corporate
# 2            woodsmelvin@yahoo.com                Halefort        Retail
# 3             tschroeder@yahoo.com              Larryhaven     Corporate
# 4        heatherfarmer@carlson.com          Christinaburgh         Fleet
# ..                             ...                     ...           ...
# 995      josephalvarez@hotmail.com               Bellville        Retail
# 996         chapmanjerry@gmail.com           North Jeanton     Corporate
# 997  jacobsonroy@martin-bailey.biz            Alvarezburgh        Retail
# 998           scottolson@clark.com       West Jessicashire         Fleet
# 999          tayloramy@hotmail.com               Sandraton        Retail
#
#     preferred_language     make   model  year_of_purchase  ...  \
# 0                Tamil     Ford  Aspire              2019  ...
# 1                Tamil   Toyota   Yaris              2019  ...
# 2              English     Ford    Figo              2020  ...
# 3              English    Honda    City              2019  ...
# 4                Hindi    Honda    City              2015  ...
# ..                 ...      ...     ...               ...  ...
# 995              Hindi  Hyundai     i20              2015  ...
# 996              Tamil  Hyundai   Creta              2016  ...
# 997              Tamil   Toyota  Innova              2021  ...
# 998              Tamil  Hyundai     i10              2015  ...
# 999              Hindi   Toyota  Innova              2016  ...
#
#      Whats_delivered Whats_clicked sent_email  clicked_email email_opened  \
# 0                 No            No         No             No           No
# 1                Yes           Yes        Yes             No          Yes
# 2                 No            No         No             No           No
# 3                 No            No        Yes            Yes           No
# 4                Yes           Yes        Yes            Yes           No
# ..               ...           ...        ...            ...          ...
# 995              Yes           Yes         No             No           No
# 996              Yes           Yes        Yes             No           No
# 997              Yes           Yes         No             No           No
# 998              Yes           Yes         No             No           No
# 999               No            No        Yes            Yes           No
#
#     last_service_cost feedback_score pickup_drop_required customer_feedback  \
# 0                9884              4                   No      Poor Service
# 1               10996              4                  Yes         Satisfied
# 2                3213              4                   No           Average
# 3                6601              5                   No    Smooth Process
# 4               14907              3                   No      Unresponsive
# ..                ...            ...                  ...               ...
# 995             11536              3                   No    Delayed Pickup
# 996              6999              4                  Yes    Smooth Process
# 997              3215              4                   No    Delayed Pickup
# 998              9804              1                   No      Unresponsive
# 999             11768              5                   No      Unresponsive
#
#      feedback_date
# 0       2024-11-04
# 1       2025-09-01
# 2       2025-08-03
# 3       2024-11-19
# 4       2024-12-30
# ..             ...
# 995     2025-02-20
# 996     2024-10-15
# 997     2025-04-15
# 998     2024-08-27
# 999     2024-10-20
#
# [1000 rows x 52 columns]

# %%
# Drop identifiers foe sensitive
df = df.drop(columns=['customer_id', 'name', 'email', 'mobile_number'])

# %%
df
# Out:
#                    location customer_type preferred_language     make   model  \
# 0    South Christianchester        Retail              Tamil     Ford  Aspire
# 1         North Jacksonfort     Corporate              Tamil   Toyota   Yaris
# 2                  Halefort        Retail            English     Ford    Figo
# 3                Larryhaven     Corporate            English    Honda    City
# 4            Christinaburgh         Fleet              Hindi    Honda    City
# ..                      ...           ...                ...      ...     ...
# 995               Bellville        Retail              Hindi  Hyundai     i20
# 996           North Jeanton     Corporate              Tamil  Hyundai   Creta
# 997            Alvarezburgh        Retail              Tamil   Toyota  Innova
# 998       West Jessicashire         Fleet              Tamil  Hyundai     i10
# 999               Sandraton        Retail              Hindi   Toyota  Innova
#
#      year_of_purchase  age_of_vehicle fuel_type transmission  \
# 0                2019               6  Electric    Automatic
# 1                2019               6  Electric    Automatic
# 2                2020               5    Diesel       Manual
# 3                2019               6    Petrol       Manual
# 4                2015              10  Electric       Manual
# ..                ...             ...       ...          ...
# 995              2015              10    Diesel       Manual
# 996              2016               9  Electric    Automatic
# 997              2021               4  Electric    Automatic
# 998              2015              10    Petrol    Automatic
# 999              2016               9    Diesel    Automatic
#
#      odometer_reading  ... Whats_delivered Whats_clicked sent_email  \
# 0               59174  ...              No            No         No
# 1               32365  ...             Yes           Yes        Yes
# 2               49576  ...              No            No         No
# 3               83890  ...              No            No        Yes
# 4               77667  ...             Yes           Yes        Yes
# ..                ...  ...             ...           ...        ...
# 995            101418  ...             Yes           Yes         No
# 996             93748  ...             Yes           Yes        Yes
# 997             52739  ...             Yes           Yes         No
# 998             66442  ...             Yes           Yes         No
# 999            101031  ...              No            No        Yes
#
#     clicked_email email_opened  last_service_cost  feedback_score  \
# 0              No           No               9884               4
# 1              No          Yes              10996               4
# 2              No           No               3213               4
# 3             Yes           No               6601               5
# 4             Yes           No              14907               3
# ..            ...          ...                ...             ...
# 995            No           No              11536               3
# 996            No           No               6999               4
# 997            No           No               3215               4
# 998            No           No               9804               1
# 999           Yes           No              11768               5
#
#      pickup_drop_required  customer_feedback feedback_date
# 0                      No       Poor Service    2024-11-04
# 1                     Yes          Satisfied    2025-09-01
# 2                      No            Average    2025-08-03
# 3                      No     Smooth Process    2024-11-19
# 4                      No       Unresponsive    2024-12-30
# ..                    ...                ...           ...
# 995                    No     Delayed Pickup    2025-02-20
# 996                   Yes     Smooth Process    2024-10-15
# 997                    No     Delayed Pickup    2025-04-15
# 998                    No       Unresponsive    2024-08-27
# 999                    No       Unresponsive    2024-10-20
#
# [1000 rows x 48 columns]

# %%
# Encode categoricals
df = pd.get_dummies(df, columns=['location', 'customer_type', 'make', 'model', 'fuel_type', 
                                 'transmission', 'service_center', 'warranty_status', 
                                 'insurance_status', 'AMC_status', 'preferred_language'])

# %%
df
# Out:
#      year_of_purchase  age_of_vehicle  odometer_reading last_service_date  \
# 0                2019               6             59174        2024-10-04
# 1                2019               6             32365        2025-05-01
# 2                2020               5             49576        2025-04-03
# 3                2019               6             83890        2024-11-18
# 4                2015              10             77667        2024-12-27
# ..                ...             ...               ...               ...
# 995              2015              10            101418        2025-02-16
# 996              2016               9             93748        2024-10-14
# 997              2021               4             52739        2025-04-14
# 998              2015              10             66442        2024-08-26
# 999              2016               9            101031        2024-10-17
#
#     last_service_type  number_of_services  last_service_kms  \
# 0               Minor                   7             56063
# 1               Major                   3             30554
# 2               Minor                   8             46881
# 3               Minor                   6             82509
# 4               Major                   4             73001
# ..                ...                 ...               ...
# 995             Major                   3             99377
# 996             Minor                   3             90539
# 997             Minor                   3             47837
# 998             Minor                   9             64525
# 999             Minor                   5             97438
#
#      avg_kms_per_month  next_service_due_kms next_service_due_date  ...  \
# 0                  811                 66063            2025-02-04  ...
# 1                  443                 40554            2025-10-28  ...
# 2                  813                 56881            2025-09-30  ...
# 3                 1149                 92509            2025-05-17  ...
# 4                  642                 83001            2025-06-25  ...
# ..                 ...                   ...                   ...  ...
# 995                838                109377            2025-08-15  ...
# 996                860                100539            2025-12-04  ...
# 997               1076                 57837            2025-11-10  ...
# 998                549                 74525            2025-02-22  ...
# 999                927                107438            2025-04-15  ...
#
#      service_center_Velachery warranty_status_Active warranty_status_Expired  \
# 0                           0                      0                       1
# 1                           0                      0                       1
# 2                           0                      0                       1
# 3                           0                      0                       1
# 4                           0                      0                       1
# ..                        ...                    ...                     ...
# 995                         0                      0                       1
# 996                         1                      0                       1
# 997                         0                      0                       1
# 998                         0                      0                       1
# 999                         0                      0                       1
#
#     insurance_status_Active insurance_status_Expired AMC_status_No  \
# 0                         0                        1             1
# 1                         1                        0             1
# 2                         0                        1             1
# 3                         0                        1             1
# 4                         1                        0             0
# ..                      ...                      ...           ...
# 995                       1                        0             0
# 996                       1                        0             0
# 997                       1                        0             1
# 998                       1                        0             1
# 999                       1                        0             0
#
#     AMC_status_Yes preferred_language_English  preferred_language_Hindi  \
# 0                0                          0                         0
# 1                0                          0                         0
# 2                0                          1                         0
# 3                0                          1                         0
# 4                1                          0                         1
# ..             ...                        ...                       ...
# 995              1                          0                         1
# 996              1                          0                         0
# 997              0                          0                         0
# 998              0                          0                         0
# 999              1                          0                         1
#
#     preferred_language_Tamil
# 0                          1
# 1                          1
# 2                          0
# 3                          0
# 4                          0
# ..                       ...
# 995                        0
# 996                        1
# 997                        1
# 998                        1
# 999                        0
#
# [1000 rows x 547 columns]

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
# Scale numerical
scaler = StandardScaler()
num_cols = ['age_of_vehicle', 'odometer_reading', 'last_service_cost', 'number_of_services']
df[num_cols] = scaler.fit_transform(df[num_cols])

# %%
df
# Out:
#      year_of_purchase  age_of_vehicle  odometer_reading last_service_date  \
# 0                2019       -0.247899         -0.206041        2024-10-04
# 1                2019       -0.247899         -1.082204        2025-05-01
# 2                2020       -0.692162         -0.519720        2025-04-03
# 3                2019       -0.247899          0.601719        2024-11-18
# 4                2015        1.529153          0.398341        2024-12-27
# ..                ...             ...               ...               ...
# 995              2015        1.529153          1.174563        2025-02-16
# 996              2016        1.084890          0.923895        2024-10-14
# 997              2021       -1.136425         -0.416348        2025-04-14
# 998              2015        1.529153          0.031489        2024-08-26
# 999              2016        1.084890          1.161915        2024-10-17
#
#     last_service_type  number_of_services  last_service_kms  \
# 0               Minor            0.560456             56063
# 1               Major           -0.907667             30554
# 2               Minor            0.927486             46881
# 3               Minor            0.193425             82509
# 4               Major           -0.540636             73001
# ..                ...                 ...               ...
# 995             Major           -0.907667             99377
# 996             Minor           -0.907667             90539
# 997             Minor           -0.907667             47837
# 998             Minor            1.294517             64525
# 999             Minor           -0.173606             97438
#
#      avg_kms_per_month  next_service_due_kms next_service_due_date  ...  \
# 0                  811                 66063            2025-02-04  ...
# 1                  443                 40554            2025-10-28  ...
# 2                  813                 56881            2025-09-30  ...
# 3                 1149                 92509            2025-05-17  ...
# 4                  642                 83001            2025-06-25  ...
# ..                 ...                   ...                   ...  ...
# 995                838                109377            2025-08-15  ...
# 996                860                100539            2025-12-04  ...
# 997               1076                 57837            2025-11-10  ...
# 998                549                 74525            2025-02-22  ...
# 999                927                107438            2025-04-15  ...
#
#      service_center_Velachery warranty_status_Active warranty_status_Expired  \
# 0                           0                      0                       1
# 1                           0                      0                       1
# 2                           0                      0                       1
# 3                           0                      0                       1
# 4                           0                      0                       1
# ..                        ...                    ...                     ...
# 995                         0                      0                       1
# 996                         1                      0                       1
# 997                         0                      0                       1
# 998                         0                      0                       1
# 999                         0                      0                       1
#
#     insurance_status_Active insurance_status_Expired AMC_status_No  \
# 0                         0                        1             1
# 1                         1                        0             1
# 2                         0                        1             1
# 3                         0                        1             1
# 4                         1                        0             0
# ..                      ...                      ...           ...
# 995                       1                        0             0
# 996                       1                        0             0
# 997                       1                        0             1
# 998                       1                        0             1
# 999                       1                        0             0
#
#     AMC_status_Yes preferred_language_English  preferred_language_Hindi  \
# 0                0                          0                         0
# 1                0                          0                         0
# 2                0                          1                         0
# 3                0                          1                         0
# 4                1                          0                         1
# ..             ...                        ...                       ...
# 995              1                          0                         1
# 996              1                          0                         0
# 997              0                          0                         0
# 998              0                          0                         0
# 999              1                          0                         1
#
#     preferred_language_Tamil
# 0                          1
# 1                          1
# 2                          0
# 3                          0
# 4                          0
# ..                       ...
# 995                        0
# 996                        1
# 997                        1
# 998                        1
# 999                        0
#
# [1000 rows x 547 columns]

# %%
#save to preprocessed data
df.to_csv('preprocessed_train_data.csv', index=False)

# %%
# !pip install fastapi
# Out:
# Collecting fastapi
#   Downloading fastapi-0.103.2-py3-none-any.whl (66 kB)
#      ---------------------------------------- 66.3/66.3 kB ? eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\anaconda3\envs\aiml\lib\site-packages (from fastapi) (4.7.1)
# Collecting starlette<0.28.0,>=0.27.0
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ---------------------------------------- 67.0/67.0 kB ? eta 0:00:00
# Collecting anyio<4.0.0,>=3.7.1
#   Downloading anyio-3.7.1-py3-none-any.whl (80 kB)
#      ---------------------------------------- 80.9/80.9 kB ? eta 0:00:00
# Collecting pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4
#   Downloading pydantic-2.5.3-py3-none-any.whl (381 kB)
#      ------------------------------------- 381.9/381.9 kB 12.0 MB/s eta 0:00:00
# Requirement already satisfied: sniffio>=1.1 in c:\anaconda3\envs\aiml\lib\site-packages (from anyio<4.0.0,>=3.7.1->fastapi) (1.2.0)
# Collecting exceptiongroup
#   Downloading exceptiongroup-1.3.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: idna>=2.8 in c:\anaconda3\envs\aiml\lib\site-packages (from anyio<4.0.0,>=3.7.1->fastapi) (3.4)
# Collecting annotated-types>=0.4.0
#   Downloading annotated_types-0.5.0-py3-none-any.whl (11 kB)
# Collecting pydantic-core==2.14.6
#   Downloading pydantic_core-2.14.6-cp37-none-win_amd64.whl (1.9 MB)
#      ---------------------------------------- 1.9/1.9 MB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata in c:\anaconda3\envs\aiml\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in c:\anaconda3\envs\aiml\lib\site-packages (from importlib-metadata->pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (3.11.0)
# Installing collected packages: pydantic-core, exceptiongroup, annotated-types, pydantic, anyio, starlette, fastapi
#   Attempting uninstall: anyio
#     Found existing installation: anyio 3.5.0
#     Uninstalling anyio-3.5.0:
#       Successfully uninstalled anyio-3.5.0
# Successfully installed annotated-types-0.5.0 anyio-3.7.1 exceptiongroup-1.3.0 fastapi-0.103.2 pydantic-2.5.3 pydantic-core-2.14.6 starlette-0.27.0
